# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key  
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=218993fcd5bfed9267582aec0558c6b9

# %%
# Pull json view to check for weather description layout
city_url = url + "&q=" + "Atlanta"
city_weather = requests.get(city_url).json()
print(city_weather)
# Out:
# {'coord': {'lon': -84.388, 'lat': 33.749}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 65.97, 'feels_like': 64.53, 'temp_min': 64.4, 'temp_max': 68, 'pressure': 1007, 'humidity': 48}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 0}, 'clouds': {'all': 1}, 'dt': 1618156523, 'sys': {'type': 1, 'id': 4155, 'country': 'US', 'sunrise': 1618139481, 'sunset': 1618185912}, 'timezone': -14400, 'id': 4180439, 'name': 'Atlanta', 'cod': 200}

# %%
#Testing weather description
city_weather["weather"][0]["description"]
# Out:
# 'clear sky'

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
       
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nikolskoye
# Processing Record 2 of Set 1 | svetlaya
# Processing Record 3 of Set 1 | haldwani
# Processing Record 4 of Set 1 | cururupu
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | victor harbor
# Processing Record 7 of Set 1 | honghu
# Processing Record 8 of Set 1 | katsuura
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | male
# Processing Record 11 of Set 1 | arraial do cabo
# Processing Record 12 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | mount gambier
# Processing Record 15 of Set 1 | kapaa
# Processing Record 16 of Set 1 | carnarvon
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | cape town
# Processing Record 19 of Set 1 | penzance
# Processing Record 20 of Set 1 | georgetown
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | kodiak
# Processing Record 23 of Set 1 | hobart
# Processing Record 24 of Set 1 | brae
# Processing Record 25 of Set 1 | airai
# Processing Record 26 of Set 1 | tecoanapa
# Processing Record 27 of Set 1 | west hartford
# Processing Record 28 of Set 1 | huarmey
# Processing Record 29 of Set 1 | san cristobal
# Processing Record 30 of Set 1 | comodoro rivadavia
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | kiama
# Processing Record 33 of Set 1 | mehriz
# Processing Record 34 of Set 1 | berlevag
# Processing Record 35 of Set 1 | itarema
# Processing Record 36 of Set 1 | hilo
# Processing Record 37 of Set 1 | opuwo
# Processing Record 38 of Set 1 | kaitangata
# Processing Record 39 of Set 1 | russell
# Processing Record 40 of Set 1 | bengkulu
# Processing Record 41 of Set 1 | kizhinga
# Processing Record 42 of Set 1 | olafsvik
# Processing Record 43 of Set 1 | luvianos
# Processing Record 44 of Set 1 | vao
# Processing Record 45 of Set 1 | portland
# Processing Record 46 of Set 1 | dikson
# Processing Record 47 of Set 1 | mehamn
# Processing Record 48 of Set 1 | griffith
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | butaritari
# Processing Record 1 of Set 2 | barrow
# Processing Record 2 of Set 2 | sychevka
# Processing Record 3 of Set 2 | awjilah
# Processing Record 4 of Set 2 | puerto ayora
# Processing Record 5 of Set 2 | broome
# Processing Record 6 of Set 2 | maniitsoq
# Processing Record 7 of Set 2 | kahului
# Processing Record 8 of Set 2 | lompoc
# Processing Record 9 of Set 2 | albany
# Processing Record 10 of Set 2 | norman wells
# Processing Record 11 of Set 2 | college
# Processing Record 12 of Set 2 | ahipara
# Processing Record 13 of Set 2 | yokadouma
# Processing Record 14 of Set 2 | farah
# Processing Record 15 of Set 2 | pangkalanbuun
# Processing Record 16 of Set 2 | cidreira
# Processing Record 17 of Set 2 | adrar
# Processing Record 18 of Set 2 | meulaboh
# Processing Record 19 of Set 2 | ponta do sol
# Processing Record 20 of Set 2 | saint-augustin
# Processing Record 21 of Set 2 | soyo
# Processing Record 22 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 2 | tuatapere
# Processing Record 24 of Set 2 | avera
# Processing Record 25 of Set 2 | deputatskiy
# Processing Record 26 of Set 2 | salalah
# Processing Record 27 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 2 | bambous virieux
# Processing Record 29 of Set 2 | linxia
# Processing Record 30 of Set 2 | port alfred
# Processing Record 31 of Set 2 | fairbanks
# Processing Record 32 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 33 of Set 2 | westport
# Processing Record 34 of Set 2 | mar del plata
# Processing Record 35 of Set 2 | hermanus
# Processing Record 36 of Set 2 | qaanaaq
# Processing Record 37 of Set 2 | ferme-neuve
# Processing Record 38 of Set 2 | boyolangu
# Processing Record 39 of Set 2 | atuona
# Processing Record 40 of Set 2 | provideniya
# Processing Record 41 of Set 2 | serebryansk
# Processing Record 42 of Set 2 | klaksvik
# Processing Record 43 of Set 2 | udachnyy
# Processing Record 44 of Set 2 | lashio
# Processing Record 45 of Set 2 | khandyga
# Processing Record 46 of Set 2 | katangli
# Processing Record 47 of Set 2 | kavieng
# Processing Record 48 of Set 2 | santiago del estero
# Processing Record 49 of Set 2 | mizan teferi
# Processing Record 50 of Set 2 | shiringushi
# Processing Record 1 of Set 3 | east london
# Processing Record 2 of Set 3 | husavik
# Processing Record 3 of Set 3 | kysyl-syr
# Processing Record 4 of Set 3 | moundsville
# Processing Record 5 of Set 3 | richards bay
# Processing Record 6 of Set 3 | acapulco
# Processing Record 7 of Set 3 | aitape
# Processing Record 8 of Set 3 | nanortalik
# Processing Record 9 of Set 3 | tshela
# Processing Record 10 of Set 3 | castro
# Processing Record 11 of Set 3 | marystown
# Processing Record 12 of Set 3 | tanete
# Processing Record 13 of Set 3 | san benito
# Processing Record 14 of Set 3 | bose
# Processing Record 15 of Set 3 | lodwar
# Processing Record 16 of Set 3 | nanakuli
# Processing Record 17 of Set 3 | werda
# Processing Record 18 of Set 3 | campo maior
# Processing Record 19 of Set 3 | port blair
# Processing Record 20 of Set 3 | zarubino
# Processing Record 21 of Set 3 | guerrero negro
# Processing Record 22 of Set 3 | leningradskiy
# Processing Record 23 of Set 3 | ormara
# Processing Record 24 of Set 3 | saldanha
# Processing Record 25 of Set 3 | torbay
# Processing Record 26 of Set 3 | clyde river
# Processing Record 27 of Set 3 | panama city
# Processing Record 28 of Set 3 | tiksi
# Processing Record 29 of Set 3 | jabinyanah
# Processing Record 30 of Set 3 | anupgarh
# Processing Record 31 of Set 3 | bathsheba
# Processing Record 32 of Set 3 | sao filipe
# Processing Record 33 of Set 3 | canmore
# Processing Record 34 of Set 3 | new norfolk
# Processing Record 35 of Set 3 | ilulissat
# Processing Record 36 of Set 3 | ancud
# Processing Record 37 of Set 3 | beringovskiy
# Processing Record 38 of Set 3 | uman
# Processing Record 39 of Set 3 | codrington
# Processing Record 40 of Set 3 | waddan
# Processing Record 41 of Set 3 | koygorodok
# Processing Record 42 of Set 3 | kirksville
# Processing Record 43 of Set 3 | malim
# Processing Record 44 of Set 3 | angoram
# Processing Record 45 of Set 3 | saskylakh
# Processing Record 46 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 3 | dejen
# Processing Record 48 of Set 3 | hobyo
# Processing Record 49 of Set 3 | domat
# Processing Record 50 of Set 3 | tricase
# Processing Record 1 of Set 4 | cayenne
# Processing Record 2 of Set 4 | alihe
# Processing Record 3 of Set 4 | lavrentiya
# Processing Record 4 of Set 4 | avarua
# Processing Record 5 of Set 4 | ulaangom
# Processing Record 6 of Set 4 | hithadhoo
# Processing Record 7 of Set 4 | mahebourg
# Processing Record 8 of Set 4 | severo-kurilsk
# Processing Record 9 of Set 4 | egvekinot
# Processing Record 10 of Set 4 | padang
# Processing Record 11 of Set 4 | sistranda
# Processing Record 12 of Set 4 | coquimbo
# Processing Record 13 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 4 | kenai
# Processing Record 15 of Set 4 | san juan
# Processing Record 16 of Set 4 | minnedosa
# Processing Record 17 of Set 4 | vaini
# Processing Record 18 of Set 4 | lasa
# Processing Record 19 of Set 4 | caravelas
# Processing Record 20 of Set 4 | haukipudas
# Processing Record 21 of Set 4 | gold coast
# Processing Record 22 of Set 4 | askiz
# Processing Record 23 of Set 4 | camacha
# Processing Record 24 of Set 4 | minas de barroteran
# Processing Record 25 of Set 4 | bredasdorp
# Processing Record 26 of Set 4 | inderborskiy
# City not found. Skipping...
# Processing Record 27 of Set 4 | paamiut
# Processing Record 28 of Set 4 | saint-denis
# Processing Record 29 of Set 4 | tocopilla
# Processing Record 30 of Set 4 | bluff
# Processing Record 31 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 4 | shuyskoye
# Processing Record 33 of Set 4 | upington
# Processing Record 34 of Set 4 | tasiilaq
# Processing Record 35 of Set 4 | santa barbara
# Processing Record 36 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 4 | cabo san lucas
# Processing Record 38 of Set 4 | masty
# Processing Record 39 of Set 4 | faya
# Processing Record 40 of Set 4 | kieta
# Processing Record 41 of Set 4 | gumdag
# Processing Record 42 of Set 4 | nagyhegyes
# Processing Record 43 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 4 | morgan city
# Processing Record 45 of Set 4 | sitka
# Processing Record 46 of Set 4 | lagoa
# Processing Record 47 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 48 of Set 4 | umm jarr
# City not found. Skipping...
# Processing Record 49 of Set 4 | vila velha
# Processing Record 50 of Set 4 | port macquarie
# Processing Record 1 of Set 5 | turukhansk
# Processing Record 2 of Set 5 | tuktoyaktuk
# Processing Record 3 of Set 5 | pisco
# Processing Record 4 of Set 5 | bethel
# Processing Record 5 of Set 5 | nyurba
# Processing Record 6 of Set 5 | valreas
# Processing Record 7 of Set 5 | road town
# Processing Record 8 of Set 5 | thompson
# Processing Record 9 of Set 5 | asyut
# Processing Record 10 of Set 5 | lebu
# Processing Record 11 of Set 5 | praia da vitoria
# Processing Record 12 of Set 5 | yellowknife
# Processing Record 13 of Set 5 | noumea
# Processing Record 14 of Set 5 | rawson
# Processing Record 15 of Set 5 | flin flon
# Processing Record 16 of Set 5 | fomboni
# Processing Record 17 of Set 5 | dakar
# Processing Record 18 of Set 5 | havelock
# Processing Record 19 of Set 5 | guarapari
# Processing Record 20 of Set 5 | khatanga
# Processing Record 21 of Set 5 | te anau
# Processing Record 22 of Set 5 | hanzhong
# Processing Record 23 of Set 5 | viedma
# Processing Record 24 of Set 5 | oktyabrskiy
# Processing Record 25 of Set 5 | svetlogorsk
# Processing Record 26 of Set 5 | bengkalis
# City not found. Skipping...
# Processing Record 27 of Set 5 | sambava
# Processing Record 28 of Set 5 | kodra
# Processing Record 29 of Set 5 | bol
# Processing Record 30 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 5 | mana
# Processing Record 33 of Set 5 | bubaque
# Processing Record 34 of Set 5 | winsum
# Processing Record 35 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 5 | belyy yar
# Processing Record 37 of Set 5 | jumla
# Processing Record 38 of Set 5 | canakkale
# Processing Record 39 of Set 5 | chute-aux-outardes
# Processing Record 40 of Set 5 | virginia beach
# Processing Record 41 of Set 5 | tilichiki
# Processing Record 42 of Set 5 | yarmouth
# Processing Record 43 of Set 5 | longyearbyen
# Processing Record 44 of Set 5 | wagar
# Processing Record 45 of Set 5 | povenets
# Processing Record 46 of Set 5 | port elizabeth
# Processing Record 47 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 48 of Set 5 | chuy
# Processing Record 49 of Set 5 | kandrian
# Processing Record 50 of Set 5 | elko
# Processing Record 1 of Set 6 | upernavik
# Processing Record 2 of Set 6 | roald
# Processing Record 3 of Set 6 | coihaique
# Processing Record 4 of Set 6 | tual
# Processing Record 5 of Set 6 | bagdarin
# Processing Record 6 of Set 6 | luderitz
# Processing Record 7 of Set 6 | iqaluit
# Processing Record 8 of Set 6 | harper
# Processing Record 9 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 6 | port arthur
# Processing Record 11 of Set 6 | perbaungan
# Processing Record 12 of Set 6 | ukiah
# Processing Record 13 of Set 6 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 14 of Set 6 | asau
# Processing Record 15 of Set 6 | porto novo
# Processing Record 16 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 6 | medford
# Processing Record 18 of Set 6 | namatanai
# Processing Record 19 of Set 6 | pevek
# Processing Record 20 of Set 6 | turbat
# Processing Record 21 of Set 6 | itoman
# Processing Record 22 of Set 6 | lorengau
# Processing Record 23 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 6 | narsaq
# Processing Record 25 of Set 6 | saint-philippe
# Processing Record 26 of Set 6 | miles city
# Processing Record 27 of Set 6 | sterling
# Processing Record 28 of Set 6 | kumluca
# Processing Record 29 of Set 6 | mubi
# Processing Record 30 of Set 6 | reftinskiy
# Processing Record 31 of Set 6 | sept-iles
# Processing Record 32 of Set 6 | chokurdakh
# Processing Record 33 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 6 | keskin
# Processing Record 35 of Set 6 | colares
# Processing Record 36 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 6 | muli
# Processing Record 38 of Set 6 | vestmanna
# Processing Record 39 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 6 | beyneu
# Processing Record 41 of Set 6 | williams lake
# Processing Record 42 of Set 6 | geraldton
# Processing Record 43 of Set 6 | axim
# Processing Record 44 of Set 6 | mount isa
# Processing Record 45 of Set 6 | ribeira grande
# Processing Record 46 of Set 6 | nouadhibou
# Processing Record 47 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 48 of Set 6 | pangnirtung
# Processing Record 49 of Set 6 | chara
# Processing Record 50 of Set 6 | remanso
# Processing Record 1 of Set 7 | muskegon
# Processing Record 2 of Set 7 | norfolk
# Processing Record 3 of Set 7 | kostinbrod
# Processing Record 4 of Set 7 | boa vista
# Processing Record 5 of Set 7 | kalmunai
# Processing Record 6 of Set 7 | mountain home
# Processing Record 7 of Set 7 | bonavista
# Processing Record 8 of Set 7 | biak
# Processing Record 9 of Set 7 | kambove
# Processing Record 10 of Set 7 | mokshan
# Processing Record 11 of Set 7 | bayir
# Processing Record 12 of Set 7 | nabire
# Processing Record 13 of Set 7 | wanaka
# Processing Record 14 of Set 7 | nichinan
# Processing Record 15 of Set 7 | north bend
# Processing Record 16 of Set 7 | rio grande
# Processing Record 17 of Set 7 | san patricio
# Processing Record 18 of Set 7 | port-gentil
# Processing Record 19 of Set 7 | solsvik
# City not found. Skipping...
# Processing Record 20 of Set 7 | porosozero
# Processing Record 21 of Set 7 | aleksandrovskoye
# Processing Record 22 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 23 of Set 7 | breves
# Processing Record 24 of Set 7 | yulara
# Processing Record 25 of Set 7 | marawi
# Processing Record 26 of Set 7 | kupang
# Processing Record 27 of Set 7 | tuy hoa
# Processing Record 28 of Set 7 | yarada
# Processing Record 29 of Set 7 | kirakira
# Processing Record 30 of Set 7 | the pas
# Processing Record 31 of Set 7 | west bay
# Processing Record 32 of Set 7 | lata
# Processing Record 33 of Set 7 | ciudad bolivar
# Processing Record 34 of Set 7 | marzuq
# Processing Record 35 of Set 7 | uddevalla
# Processing Record 36 of Set 7 | arman
# Processing Record 37 of Set 7 | salinopolis
# Processing Record 38 of Set 7 | komsomolskiy
# Processing Record 39 of Set 7 | minamata
# Processing Record 40 of Set 7 | namibe
# Processing Record 41 of Set 7 | sarahan
# Processing Record 42 of Set 7 | iraucuba
# Processing Record 43 of Set 7 | vila
# Processing Record 44 of Set 7 | sarangani
# Processing Record 45 of Set 7 | adre
# Processing Record 46 of Set 7 | unye
# City not found. Skipping...
# Processing Record 47 of Set 7 | krasnoselkup
# Processing Record 48 of Set 7 | sal rei
# Processing Record 49 of Set 7 | monjas
# Processing Record 50 of Set 7 | sofiysk
# City not found. Skipping...
# Processing Record 1 of Set 8 | san juan de uraba
# Processing Record 2 of Set 8 | la palma
# Processing Record 3 of Set 8 | rabo de peixe
# Processing Record 4 of Set 8 | leonidovo
# Processing Record 5 of Set 8 | hervey bay
# Processing Record 6 of Set 8 | cap malheureux
# Processing Record 7 of Set 8 | tabialan
# City not found. Skipping...
# Processing Record 8 of Set 8 | san luis
# Processing Record 9 of Set 8 | neepawa
# Processing Record 10 of Set 8 | ballina
# Processing Record 11 of Set 8 | lebedinyy
# Processing Record 12 of Set 8 | gornopravdinsk
# Processing Record 13 of Set 8 | weatherford
# Processing Record 14 of Set 8 | matara
# Processing Record 15 of Set 8 | bracebridge
# Processing Record 16 of Set 8 | ranong
# Processing Record 17 of Set 8 | necochea
# Processing Record 18 of Set 8 | koumac
# Processing Record 19 of Set 8 | great yarmouth
# Processing Record 20 of Set 8 | esperance
# Processing Record 21 of Set 8 | paignton
# Processing Record 22 of Set 8 | kemijarvi
# Processing Record 23 of Set 8 | vyartsilya
# Processing Record 24 of Set 8 | thinadhoo
# Processing Record 25 of Set 8 | jacareacanga
# Processing Record 26 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 27 of Set 8 | that phanom
# Processing Record 28 of Set 8 | havoysund
# Processing Record 29 of Set 8 | bandarbeyla
# Processing Record 30 of Set 8 | shache
# Processing Record 31 of Set 8 | ornskoldsvik
# Processing Record 32 of Set 8 | nguru
# Processing Record 33 of Set 8 | bima
# Processing Record 34 of Set 8 | westpunt
# City not found. Skipping...
# Processing Record 35 of Set 8 | mecca
# Processing Record 36 of Set 8 | cherskiy
# Processing Record 37 of Set 8 | churapcha
# Processing Record 38 of Set 8 | letka
# Processing Record 39 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 40 of Set 8 | mabay
# Processing Record 41 of Set 8 | talnakh
# Processing Record 42 of Set 8 | saint george
# Processing Record 43 of Set 8 | norsup
# Processing Record 44 of Set 8 | ferrol
# Processing Record 45 of Set 8 | himora
# City not found. Skipping...
# Processing Record 46 of Set 8 | zyryanka
# Processing Record 47 of Set 8 | yuzhno-sukhokumsk
# Processing Record 48 of Set 8 | octeville
# Processing Record 49 of Set 8 | tura
# Processing Record 50 of Set 8 | eldikan
# City not found. Skipping...
# Processing Record 1 of Set 9 | los llanos de aridane
# Processing Record 2 of Set 9 | kattivakkam
# Processing Record 3 of Set 9 | phek
# Processing Record 4 of Set 9 | tautira
# Processing Record 5 of Set 9 | atar
# Processing Record 6 of Set 9 | yanam
# Processing Record 7 of Set 9 | jibuti
# Processing Record 8 of Set 9 | praya
# Processing Record 9 of Set 9 | umm lajj
# Processing Record 10 of Set 9 | cao bang
# Processing Record 11 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 9 | kavaratti
# Processing Record 13 of Set 9 | ostrovnoy
# Processing Record 14 of Set 9 | vestmannaeyjar
# Processing Record 15 of Set 9 | straumen
# Processing Record 16 of Set 9 | buta
# Processing Record 17 of Set 9 | yar-sale
# Processing Record 18 of Set 9 | grand gaube
# Processing Record 19 of Set 9 | faanui
# Processing Record 20 of Set 9 | pingliang
# Processing Record 21 of Set 9 | zhicheng
# Processing Record 22 of Set 9 | souillac
# Processing Record 23 of Set 9 | grande prairie
# Processing Record 24 of Set 9 | laguna
# Processing Record 25 of Set 9 | benguela
# Processing Record 26 of Set 9 | la rioja
# Processing Record 27 of Set 9 | milas
# Processing Record 28 of Set 9 | eyl
# Processing Record 29 of Set 9 | gat
# Processing Record 30 of Set 9 | aleppo
# Processing Record 31 of Set 9 | najran
# Processing Record 32 of Set 9 | dongsheng
# Processing Record 33 of Set 9 | alofi
# Processing Record 34 of Set 9 | freeport
# Processing Record 35 of Set 9 | mikuni
# Processing Record 36 of Set 9 | kayanga
# Processing Record 37 of Set 9 | victoria
# Processing Record 38 of Set 9 | kruisfontein
# Processing Record 39 of Set 9 | kota belud
# Processing Record 40 of Set 9 | lenger
# Processing Record 41 of Set 9 | jijiga
# Processing Record 42 of Set 9 | ayia galini
# Processing Record 43 of Set 9 | suzu
# City not found. Skipping...
# Processing Record 44 of Set 9 | bedele
# Processing Record 45 of Set 9 | bemidji
# Processing Record 46 of Set 9 | znamenskoye
# Processing Record 47 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 48 of Set 9 | san quintin
# Processing Record 49 of Set 9 | benghazi
# Processing Record 50 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 10 | noboribetsu
# Processing Record 2 of Set 10 | beira
# Processing Record 3 of Set 10 | havre-saint-pierre
# Processing Record 4 of Set 10 | aklavik
# Processing Record 5 of Set 10 | nador
# Processing Record 6 of Set 10 | peachland
# Processing Record 7 of Set 10 | markova
# Processing Record 8 of Set 10 | yumen
# Processing Record 9 of Set 10 | bireun
# Processing Record 10 of Set 10 | berovo
# Processing Record 11 of Set 10 | ipua
# Processing Record 12 of Set 10 | mangrol
# Processing Record 13 of Set 10 | hambantota
# Processing Record 14 of Set 10 | hasaki
# Processing Record 15 of Set 10 | dneprovskaya
# Processing Record 16 of Set 10 | port hardy
# Processing Record 17 of Set 10 | san francisco del mar
# Processing Record 18 of Set 10 | jonuta
# Processing Record 19 of Set 10 | ayan
# Processing Record 20 of Set 10 | northam
# Processing Record 21 of Set 10 | mareeba
# Processing Record 22 of Set 10 | taoudenni
# Processing Record 23 of Set 10 | gazli
# Processing Record 24 of Set 10 | karratha
# Processing Record 25 of Set 10 | pokanayevka
# City not found. Skipping...
# Processing Record 26 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 27 of Set 10 | altus
# Processing Record 28 of Set 10 | hofn
# Processing Record 29 of Set 10 | urumqi
# Processing Record 30 of Set 10 | gambela
# Processing Record 31 of Set 10 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 32 of Set 10 | devils lake
# Processing Record 33 of Set 10 | fort nelson
# Processing Record 34 of Set 10 | korcula
# Processing Record 35 of Set 10 | oussouye
# Processing Record 36 of Set 10 | mabaruma
# Processing Record 37 of Set 10 | olden
# Processing Record 38 of Set 10 | sola
# Processing Record 39 of Set 10 | evensk
# Processing Record 40 of Set 10 | okhotsk
# Processing Record 41 of Set 10 | veinticinco de mayo
# Processing Record 42 of Set 10 | koutsouras
# Processing Record 43 of Set 10 | les cayes
# Processing Record 44 of Set 10 | almora
# Processing Record 45 of Set 10 | kibala
# Processing Record 46 of Set 10 | saint anthony
# Processing Record 47 of Set 10 | haapiti
# Processing Record 48 of Set 10 | hurghada
# Processing Record 49 of Set 10 | takhtamygda
# Processing Record 50 of Set 10 | mbandaka
# Processing Record 1 of Set 11 | hualmay
# Processing Record 2 of Set 11 | san antonio
# Processing Record 3 of Set 11 | wattegama
# Processing Record 4 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 5 of Set 11 | coahuayana
# Processing Record 6 of Set 11 | quelimane
# Processing Record 7 of Set 11 | jablanica
# Processing Record 8 of Set 11 | poum
# Processing Record 9 of Set 11 | jalu
# Processing Record 10 of Set 11 | jambi
# Processing Record 11 of Set 11 | roma
# Processing Record 12 of Set 11 | esqueda
# Processing Record 13 of Set 11 | xanlar
# Processing Record 14 of Set 11 | rocha
# Processing Record 15 of Set 11 | batemans bay
# Processing Record 16 of Set 11 | saint-pierre
# Processing Record 17 of Set 11 | dire dawa
# Processing Record 18 of Set 11 | touros
# Processing Record 19 of Set 11 | luanda
# Processing Record 20 of Set 11 | genoa
# Processing Record 21 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 22 of Set 11 | kolvereid
# Processing Record 23 of Set 11 | vila franca do campo
# Processing Record 24 of Set 11 | muyezerskiy
# Processing Record 25 of Set 11 | isangel
# Processing Record 26 of Set 11 | vila do maio
# Processing Record 27 of Set 11 | san ignacio
# Processing Record 28 of Set 11 | rio de oro
# Processing Record 29 of Set 11 | salinas
# Processing Record 30 of Set 11 | sakakah
# Processing Record 31 of Set 11 | mitsamiouli
# Processing Record 32 of Set 11 | inndyr
# Processing Record 33 of Set 11 | pointe michel
# Processing Record 34 of Set 11 | tra vinh
# Processing Record 35 of Set 11 | uglovskoye
# Processing Record 36 of Set 11 | moron
# Processing Record 37 of Set 11 | gorontalo
# Processing Record 38 of Set 11 | monte patria
# Processing Record 39 of Set 11 | slave lake
# Processing Record 40 of Set 11 | santa fe
# Processing Record 41 of Set 11 | lokosovo
# Processing Record 42 of Set 11 | mayo
# Processing Record 43 of Set 11 | santa isabel
# Processing Record 44 of Set 11 | tatawin
# Processing Record 45 of Set 11 | qandahar
# City not found. Skipping...
# Processing Record 46 of Set 11 | sao joao da barra
# Processing Record 47 of Set 11 | langsa
# Processing Record 48 of Set 11 | san rafael
# Processing Record 49 of Set 11 | luau
# Processing Record 50 of Set 11 | aiquile
# Processing Record 1 of Set 12 | nioro
# Processing Record 2 of Set 12 | turayf
# Processing Record 3 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 4 of Set 12 | plouzane
# Processing Record 5 of Set 12 | vardo
# Processing Record 6 of Set 12 | llanes
# Processing Record 7 of Set 12 | kudahuvadhoo
# Processing Record 8 of Set 12 | joao camara
# Processing Record 9 of Set 12 | mogwase
# Processing Record 10 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 11 of Set 12 | balikpapan
# Processing Record 12 of Set 12 | tutoia
# Processing Record 13 of Set 12 | tondano
# Processing Record 14 of Set 12 | aasiaat
# Processing Record 15 of Set 12 | grindavik
# Processing Record 16 of Set 12 | tandalti
# Processing Record 17 of Set 12 | grand forks
# Processing Record 18 of Set 12 | makakilo city
# Processing Record 19 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 20 of Set 12 | bosaso
# Processing Record 21 of Set 12 | rantauprapat
# Processing Record 22 of Set 12 | hutchinson
# Processing Record 23 of Set 12 | shakawe
# Processing Record 24 of Set 12 | osakarovka
# Processing Record 25 of Set 12 | flinders
# Processing Record 26 of Set 12 | dunedin
# Processing Record 27 of Set 12 | sur
# Processing Record 28 of Set 12 | dori
# Processing Record 29 of Set 12 | bentiu
# Processing Record 30 of Set 12 | half moon bay
# Processing Record 31 of Set 12 | nishihara
# Processing Record 32 of Set 12 | pangai
# Processing Record 33 of Set 12 | hay river
# Processing Record 34 of Set 12 | cazaje
# City not found. Skipping...
# Processing Record 35 of Set 12 | pacific grove
# Processing Record 36 of Set 12 | sorong
# Processing Record 37 of Set 12 | almaznyy
# Processing Record 38 of Set 12 | zhigansk
# Processing Record 39 of Set 12 | zlatoustovsk
# City not found. Skipping...
# Processing Record 40 of Set 12 | cockburn town
# Processing Record 41 of Set 12 | lazaro cardenas
# Processing Record 42 of Set 12 | tallahassee
# Processing Record 43 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 12 | aljezur
# Processing Record 45 of Set 12 | wadi maliz
# Processing Record 46 of Set 12 | bilibino
# Processing Record 47 of Set 12 | lozova
# Processing Record 48 of Set 12 | baltiysk
# Processing Record 49 of Set 12 | samarai
# Processing Record 50 of Set 12 | constitucion
# Processing Record 1 of Set 13 | temuco
# Processing Record 2 of Set 13 | nhulunbuy
# Processing Record 3 of Set 13 | cozumel
# Processing Record 4 of Set 13 | sycow
# Processing Record 5 of Set 13 | tetouan
# Processing Record 6 of Set 13 | howard springs
# Processing Record 7 of Set 13 | carinhanha
# Processing Record 8 of Set 13 | daru
# Processing Record 9 of Set 13 | erzin
# Processing Record 10 of Set 13 | redlands
# Processing Record 11 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 12 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 13 of Set 13 | maunatlala
# Processing Record 14 of Set 13 | fonte boa
# Processing Record 15 of Set 13 | pokrovsk
# Processing Record 16 of Set 13 | sydney
# Processing Record 17 of Set 13 | yakima
# Processing Record 18 of Set 13 | praia
# Processing Record 19 of Set 13 | plainview
# Processing Record 20 of Set 13 | tiruvottiyur
# City not found. Skipping...
# Processing Record 21 of Set 13 | laguna de perlas
# Processing Record 22 of Set 13 | wajima
# Processing Record 23 of Set 13 | folldal
# Processing Record 24 of Set 13 | pavlodar
# Processing Record 25 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 26 of Set 13 | hami
# Processing Record 27 of Set 13 | bonthe
# Processing Record 28 of Set 13 | anloga
# Processing Record 29 of Set 13 | dourbali
# Processing Record 30 of Set 13 | henties bay
# Processing Record 31 of Set 13 | high level
# Processing Record 32 of Set 13 | trang
# Processing Record 33 of Set 13 | camabatela
# Processing Record 34 of Set 13 | xucheng
# Processing Record 35 of Set 13 | tommot
# Processing Record 36 of Set 13 | talcahuano
# Processing Record 37 of Set 13 | burica
# City not found. Skipping...
# Processing Record 38 of Set 13 | binzhou
# Processing Record 39 of Set 13 | olinda
# Processing Record 40 of Set 13 | bulgan
# Processing Record 41 of Set 13 | ca mau
# Processing Record 42 of Set 13 | botevgrad
# Processing Record 43 of Set 13 | labuhan
# Processing Record 44 of Set 13 | lengshuijiang
# Processing Record 45 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 46 of Set 13 | dingle
# Processing Record 47 of Set 13 | phan thiet
# Processing Record 48 of Set 13 | kyabe
# Processing Record 49 of Set 13 | anadyr
# Processing Record 50 of Set 13 | myre
# Processing Record 1 of Set 14 | kabinda
# Processing Record 2 of Set 14 | asfi
# Processing Record 3 of Set 14 | bilma
# Processing Record 4 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 5 of Set 14 | butembo
# Processing Record 6 of Set 14 | kizukuri
# Processing Record 7 of Set 14 | lao cai
# Processing Record 8 of Set 14 | buritis
# Processing Record 9 of Set 14 | emerald
# Processing Record 10 of Set 14 | livani
# Processing Record 11 of Set 14 | mezhdurechensk
# Processing Record 12 of Set 14 | karlskrona
# Processing Record 13 of Set 14 | yushan
# Processing Record 14 of Set 14 | sindou
# Processing Record 15 of Set 14 | west plains
# Processing Record 16 of Set 14 | russkiy aktash
# Processing Record 17 of Set 14 | malkara
# Processing Record 18 of Set 14 | katsiveli
# City not found. Skipping...
# Processing Record 19 of Set 14 | itapetinga
# Processing Record 20 of Set 14 | diego de almagro
# Processing Record 21 of Set 14 | kuching
# Processing Record 22 of Set 14 | valley city
# Processing Record 23 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 14 | hof
# Processing Record 25 of Set 14 | quesnel
# Processing Record 26 of Set 14 | mantua
# Processing Record 27 of Set 14 | polohy
# Processing Record 28 of Set 14 | port hedland
# Processing Record 29 of Set 14 | pyaozerskiy
# Processing Record 30 of Set 14 | te karaka
# Processing Record 31 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 32 of Set 14 | ende
# Processing Record 33 of Set 14 | mackenzie
# Processing Record 34 of Set 14 | tiznit
# Processing Record 35 of Set 14 | preganziol
# Processing Record 36 of Set 14 | diamantino
# Processing Record 37 of Set 14 | singkang
# Processing Record 38 of Set 14 | fort pierce
# Processing Record 39 of Set 14 | sao geraldo do araguaia
# Processing Record 40 of Set 14 | aswan
# Processing Record 41 of Set 14 | jawar
# Processing Record 42 of Set 14 | fortuna
# Processing Record 43 of Set 14 | imbituba
# Processing Record 44 of Set 14 | chizhou
# Processing Record 45 of Set 14 | watertown
# Processing Record 46 of Set 14 | omboue
# Processing Record 47 of Set 14 | kamenskiy
# Processing Record 48 of Set 14 | akyab
# Processing Record 49 of Set 14 | davila
# Processing Record 50 of Set 14 | kailua
# Processing Record 1 of Set 15 | maragogi
# Processing Record 2 of Set 15 | grafton
# Processing Record 3 of Set 15 | eureka
# Processing Record 4 of Set 15 | verkhovazhye
# Processing Record 5 of Set 15 | thunder bay
# Processing Record 6 of Set 15 | belmonte
# Processing Record 7 of Set 15 | palmital
# Processing Record 8 of Set 15 | la ronge
# Processing Record 9 of Set 15 | cabedelo
# Processing Record 10 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 11 of Set 15 | tazovskiy
# Processing Record 12 of Set 15 | marondera
# Processing Record 13 of Set 15 | rodrigues alves
# Processing Record 14 of Set 15 | morondava
# Processing Record 15 of Set 15 | miracema do tocantins
# Processing Record 16 of Set 15 | alice springs
# Processing Record 17 of Set 15 | tocache
# Processing Record 18 of Set 15 | fairview
# Processing Record 19 of Set 15 | garden city
# Processing Record 20 of Set 15 | raga
# Processing Record 21 of Set 15 | santa maria
# Processing Record 22 of Set 15 | kijang
# Processing Record 23 of Set 15 | broken hill
# Processing Record 24 of Set 15 | pompeu
# Processing Record 25 of Set 15 | jadu
# Processing Record 26 of Set 15 | buraydah
# Processing Record 27 of Set 15 | yinchuan
# Processing Record 28 of Set 15 | korsor
# Processing Record 29 of Set 15 | haines junction
# Processing Record 30 of Set 15 | tenenkou
# Processing Record 31 of Set 15 | kununurra
# Processing Record 32 of Set 15 | newport
# Processing Record 33 of Set 15 | jacqueville
# Processing Record 34 of Set 15 | ekhabi
# Processing Record 35 of Set 15 | mazulskiy
# City not found. Skipping...
# Processing Record 36 of Set 15 | oktyabrskoye
# Processing Record 37 of Set 15 | namtsy
# Processing Record 38 of Set 15 | aden
# Processing Record 39 of Set 15 | sinnar
# Processing Record 40 of Set 15 | keetmanshoop
# Processing Record 41 of Set 15 | champua
# Processing Record 42 of Set 15 | harsum
# Processing Record 43 of Set 15 | lakatoro
# Processing Record 44 of Set 15 | launceston
# Processing Record 45 of Set 15 | cartagena
# Processing Record 46 of Set 15 | millinocket
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Nikolskoye  59.7035   30.7861     50.00        32           0
# 1         Svetlaya  46.5389  138.3297     41.32        79         100
# 2         Haldwani  29.2167   79.5167     78.22         9           0
# 3         Cururupu  -1.8283  -44.8683     85.89        63          96
# 4          Rikitea -23.1203 -134.9692     78.28        75           9
# 5    Victor Harbor -35.5667  138.6167     60.01        65          67
# 6           Honghu  29.8206  113.4621     57.70        96         100
# 7         Katsuura  35.1333  140.3000     55.40        76          20
# 8             Male   4.1748   73.5089     86.00        79          20
# 9  Arraial Do Cabo -22.9661  -42.0278     87.80        37           0
#
#    Wind Speed Country                 Date Current Description
# 0        6.71      RU  2021-04-11 15:56:16           clear sky
# 1        9.33      RU  2021-04-11 15:56:17     overcast clouds
# 2        7.02      IN  2021-04-11 15:56:17           clear sky
# 3        6.96      BR  2021-04-11 15:56:17          light rain
# 4       10.71      PF  2021-04-11 15:56:18           clear sky
# 5        7.34      AU  2021-04-11 15:56:18       broken clouds
# 6        2.84      CN  2021-04-11 15:56:19     overcast clouds
# 7        6.91      JP  2021-04-11 15:56:19          few clouds
# 8        5.75      MV  2021-04-11 15:56:19          few clouds
# 9        5.75      BR  2021-04-11 15:56:20           clear sky

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
city_data_df
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0     Nikolskoye      RU  2021-04-11 15:56:16  59.7035   30.7861     50.00
# 1       Svetlaya      RU  2021-04-11 15:56:17  46.5389  138.3297     41.32
# 2       Haldwani      IN  2021-04-11 15:56:17  29.2167   79.5167     78.22
# 3       Cururupu      BR  2021-04-11 15:56:17  -1.8283  -44.8683     85.89
# 4        Rikitea      PF  2021-04-11 15:56:18 -23.1203 -134.9692     78.28
# ..           ...     ...                  ...      ...       ...       ...
# 678       Harsum      DE  2021-04-11 16:00:15  52.2104    9.9649     42.01
# 679     Lakatoro      VU  2021-04-11 16:00:16 -16.0999  167.4164     77.56
# 680   Launceston      AU  2021-04-11 16:00:16 -41.4500  147.1667     46.40
# 681    Cartagena      CO  2021-04-11 16:00:17  10.3997  -75.5144     86.00
# 682  Millinocket      US  2021-04-11 16:00:17  45.6573  -68.7098     44.60
#
#      Humidity  Cloudiness  Wind Speed Current Description
# 0          32           0        6.71           clear sky
# 1          79         100        9.33     overcast clouds
# 2           9           0        7.02           clear sky
# 3          63          96        6.96          light rain
# 4          75           9       10.71           clear sky
# ..        ...         ...         ...                 ...
# 678        88         100        8.01       moderate rain
# 679        86         100        2.77     overcast clouds
# 680        57          40        6.91    scattered clouds
# 681        74          20        8.05          few clouds
# 682        57           1        5.48           clear sky
#
# [683 rows x 10 columns]
